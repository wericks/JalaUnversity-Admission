# %%
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>> aula 2 >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
robot_art = r"""
      0: {head_name}
      Is available: {head_status}
      Attack: {head_attack}                              
      Defense: {head_defense}
      Energy consumption: {head_energy_consump}
              ^
              |                  |1: {weapon_name}
              |                  |Is available: {weapon_status}
     ____     |    ____          |Attack: {weapon_attack}
    |oooo|  ____  |oooo| ------> |Defense: {weapon_defense}
    |oooo| '    ' |oooo|         |Energy consumption: {weapon_energy_consump}
    |oooo|/\_||_/\|oooo|          
    `----' / __ \  `----'           |2: {left_arm_name}
   '/  |#|/\/__\/\|#|  \'           |Is available: {left_arm_status}
   /  \|#|| |/\| ||#|/  \           |Attack: {left_arm_attack}
  / \_/|_|| |/\| ||_|\_/ \          |Defense: {left_arm_defense}
 |_\/    O\=----=/O    \/_|         |Energy consumption: {left_arm_energy_consump}
 <_>      |=\__/=|      <_> ------> |
 <_>      |------|      <_>         |3: {right_arm_name}
 | |   ___|======|___   | |         |Is available: {right_arm_status}
// \\ / |O|======|O| \  //\\        |Attack: {right_arm_attack}
|  |  | |O+------+O| |  |  |        |Defense: {right_arm_defense}
|\/|  \_+/        \+_/  |\/|        |Energy consumption: {right_arm_energy_consump}
\__/  _|||        |||_  \__/        
      | ||        || |          |4: {left_leg_name} 
     [==|]        [|==]         |Is available: {left_leg_status}
     [===]        [===]         |Attack: {left_leg_attack}
      >_<          >_<          |Defense: {left_leg_defense}
     || ||        || ||         |Energy consumption: {left_leg_energy_consump}
     || ||        || || ------> |
     || ||        || ||         |5: {right_leg_name}
   __|\_/|__    __|\_/|__       |Is available: {right_leg_status}
  /___n_n___\  /___n_n___\      |Attack: {right_leg_attack}
                                |Defense: {right_leg_defense}
                                |Energy consumption: {right_leg_energy_consump}

"""

colors = {
    "preto": '\x1b[90m',
    "azul": '\x1b[94m',
    "ciano": '\x1b[96m',
    "verde": '\x1b[92m',
    "magenta": '\x1b[95m',
    "vermelho": '\x1b[91m',
    "branco": '\x1b[97m',
    "amarelo": '\x1b[93m',

    # "Black": '\x1b[90m',
    # "Blue": '\x1b[94m',
    # "Cyan": '\x1b[96m',
    # "Green": '\x1b[92m',
    # "Magenta": '\x1b[95m',
    # "Red": '\x1b[91m',
    # "White": '\x1b[97m',
    # "Yellow":'\x1b[93m',

}


# <<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<

# >>>>>>>>>>>>>>>>>>>>>>>> aula 1 >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
class Part:

    def __init__(self, name: str, attack_level=0, defense_level=0, energy_consumption=0):
        self.name = name
        self.attack_level = attack_level
        self.defense_level = defense_level
        self.energy_consumption = energy_consumption
        # self.life_points = life_points

    def get_status_dict(self):
        formatted_name = self.name.replace(" ", "_").lower()
        return {
            "{}_name".format(formatted_name): self.name.upper(),
            "{}_status".format(formatted_name): self.is_available(),
            "{}_attack".format(formatted_name): self.attack_level,
            "{}_defense".format(formatted_name): self.defense_level,
            "{}_energy_consump".format(formatted_name): self.energy_consumption,
            # "{}_life_points".format(formatted_name): self.life_points,
        }

    def reduce_edefense(self, attack_level):
        self.defense_level -= attack_level
        if self.defense_level <= 0:
            self.defense_level = 0

    def is_available(self):
        return self.defense_level > 0


class Robot:

    def __init__(self, name, color_code):
        self.name = name
        self.color_code = color_code
        self.energy = 100
        # self.life_points = 100

        self.parts = [
            Part("Head", attack_level=10, defense_level=10, energy_consumption=5),
            Part("Weapon", attack_level=25, defense_level=0, energy_consumption=20),
            Part("Left Arm", attack_level=16, defense_level=20, energy_consumption=10),
            Part("Right Arm", attack_level=16, defense_level=20, energy_consumption=10),
            Part("Left Leg", attack_level=18, defense_level=20, energy_consumption=15),
            Part("Right Leg", attack_level=18, defense_level=20, energy_consumption=15),
        ]

    def print_status(self):
        print(self.color_code)
        str_robot = robot_art.format(**self.get_part_status())
        self.greet()
        self.print_energy()
        print(str_robot)
        # print(colors["Branco"])

    def greet(self):
        print("Olá, meu nome é:", self.name)

    def print_energy(self):
        print("Temos", self.energy, "porcento de Energia restante")

    # <<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<

    # >>>>>>>>>>>>>>>>>>>>>>>>>>>>> aula 3 >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
    def get_part_status(self):
        part_status = {}
        for part in self.parts:
            status_dict = part.get_status_dict()
            part_status.update(status_dict)
        return part_status

    def is_there_available_part(self):
        conta = 0
        for part in self.parts:
            if part.is_available():
                return True
            elif not part.is_available():
                conta += 1
                if conta == 3:
                    return "Robo destruido"
                break

        return False

    def is_on(self):
        return self.energy > 0

    # <<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<

    # >>>>>>>>>>>>>>>>>>>>>> aula 4 >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
    def attack(self, enemy_robot, part_to_use, part_to_attack):
        enemy_robot.parts[part_to_attack].reduce_edefense(self.parts[part_to_use].attack_level)
        self.energy -= self.parts[part_to_use].energy_consumption

    # <<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<

    # >>>>>>>>>>>>>>>>>>>>>>> aula 5 >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
    def get_part_status(self):
        part_status = {}
        for part in self.parts:
            status_dict = part.get_status_dict()
            part_status.update(status_dict)
        return part_status


def build_robot():
    robot_name = input("Nome do Robô: ")
    color_code = choose_color()
    robot = Robot(robot_name, color_code)
    robot.print_status()
    return robot


def choose_color():
    available_colors = colors
    print("Cores disponíveis:")

    for key, value in available_colors.items():
        print(value, key.capitalize())
    # print(colors["Branco"])
    chosen_color = input("Escolha uma cor: ").casefold()

    while chosen_color not in available_colors:
        chosen_color = input("Escolha uma cor válida: ").casefold()
    color_code = available_colors[chosen_color]

    return color_code


# <<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<

# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>> Aula 6 >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>

def play():
    playing = True
    print("Welcome to the game!")
    print("Datas for player 1:")
    robot_one = build_robot()
    # print("Dados para jogar 2: ")
    print("Datas for player 2:")
    robot_two = build_robot()

    # current_robot = robot_one
    # enemy_robot = robot_two
    rount = 0

    while playing:

        if rount % 2 == 0:
            current_robot = robot_one
            enemy_robot = robot_two
        else:
            current_robot = robot_two
            enemy_robot = robot_one

        current_robot.print_status()
        print("What part should I use to attack?:")
        part_to_use = int(input("Choose a number part: "))
        if not current_robot.is_there_available_part():
            print(f"Parte {part_to_use} foi destruida")
            part_to_use = int(input("escolha outra parte: "))

        # part_to_use = int(input("Escolha outro numero de parte: "))

        # part_to_use = int(part_to_use)

        enemy_robot.print_status()
        print("Which part of the enemy should we attack?")
        part_to_attack = int(input("Choose a enemy number part to attack: "))
        # part_to_attack = int(part_to_attack)

        current_robot.attack(enemy_robot, part_to_use, part_to_attack)
        rount += 1

        if not enemy_robot.is_on() or enemy_robot.is_there_available_part() == False:
            playing = False
            print("Congratulations, you won")


play()

# <<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
# Out:
# Welcome to the game!
# Datas for player 1:
# Nome do Robô: ko
# Cores disponíveis:
#  Preto
#  Azul
#  Ciano
#  Verde
#  Magenta
#  Vermelho
#  Branco
#  Amarelo
# Escolha uma cor: ciano
#
# Olá, meu nome é: ko
# Temos 100 porcento de Energia restante
#
#       0: HEAD
#       Is available: True
#       Attack: 10
#       Defense: 10
#       Energy consumption: 5
#               ^
#               |                  |1: WEAPON
#               |                  |Is available: False
#      ____     |    ____          |Attack: 25
#     |oooo|  ____  |oooo| ------> |Defense: 0
#     |oooo| '    ' |oooo|         |Energy consumption: 20
#     |oooo|/\_||_/\|oooo|
#     `----' / __ \  `----'           |2: LEFT ARM
#    '/  |#|/\/__\/\|#|  \'           |Is available: True
#    /  \|#|| |/\| ||#|/  \           |Attack: 16
#   / \_/|_|| |/\| ||_|\_/ \          |Defense: 20
#  |_\/    O\=----=/O    \/_|         |Energy consumption: 10
#  <_>      |=\__/=|      <_> ------> |
#  <_>      |------|      <_>         |3: RIGHT ARM
#  | |   ___|======|___   | |         |Is available: True
# // \\ / |O|======|O| \  //\\        |Attack: 16
# |  |  | |O+------+O| |  |  |        |Defense: 20
# |\/|  \_+/        \+_/  |\/|        |Energy consumption: 10
# \__/  _|||        |||_  \__/
#       | ||        || |          |4: LEFT LEG
#      [==|]        [|==]         |Is available: True
#      [===]        [===]         |Attack: 18
#       >_<          >_<          |Defense: 20
#      || ||        || ||         |Energy consumption: 15
#      || ||        || || ------> |
#      || ||        || ||         |5: RIGHT LEG
#    __|\_/|__    __|\_/|__       |Is available: True
#   /___n_n___\  /___n_n___\      |Attack: 18
#                                 |Defense: 20
#                                 |Energy consumption: 15
#
#
# Datas for player 2:
# Nome do Robô: hu
# Cores disponíveis:
#  Preto
#  Azul
#  Ciano
#  Verde
#  Magenta
#  Vermelho
#  Branco
#  Amarelo
# Escolha uma cor: vermel
# Escolha uma cor válida: vermelha
# Escolha uma cor válida: vermelha
# Escolha uma cor válida: vermelho
#
# Olá, meu nome é: hu
# Temos 100 porcento de Energia restante
#
#       0: HEAD
#       Is available: True
#       Attack: 10
#       Defense: 10
#       Energy consumption: 5
#               ^
#               |                  |1: WEAPON
#               |                  |Is available: False
#      ____     |    ____          |Attack: 25
#     |oooo|  ____  |oooo| ------> |Defense: 0
#     |oooo| '    ' |oooo|         |Energy consumption: 20
#     |oooo|/\_||_/\|oooo|
#     `----' / __ \  `----'           |2: LEFT ARM
#    '/  |#|/\/__\/\|#|  \'           |Is available: True
#    /  \|#|| |/\| ||#|/  \           |Attack: 16
#   / \_/|_|| |/\| ||_|\_/ \          |Defense: 20
#  |_\/    O\=----=/O    \/_|         |Energy consumption: 10
#  <_>      |=\__/=|      <_> ------> |
#  <_>      |------|      <_>         |3: RIGHT ARM
#  | |   ___|======|___   | |         |Is available: True
# // \\ / |O|======|O| \  //\\        |Attack: 16
# |  |  | |O+------+O| |  |  |        |Defense: 20
# |\/|  \_+/        \+_/  |\/|        |Energy consumption: 10
# \__/  _|||        |||_  \__/
#       | ||        || |          |4: LEFT LEG
#      [==|]        [|==]         |Is available: True
#      [===]        [===]         |Attack: 18
#       >_<          >_<          |Defense: 20
#      || ||        || ||         |Energy consumption: 15
#      || ||        || || ------> |
#      || ||        || ||         |5: RIGHT LEG
#    __|\_/|__    __|\_/|__       |Is available: True
#   /___n_n___\  /___n_n___\      |Attack: 18
#                                 |Defense: 20
#                                 |Energy consumption: 15
#
#
#
# Olá, meu nome é: ko
# Temos 100 porcento de Energia restante
#
#       0: HEAD
#       Is available: True
#       Attack: 10
#       Defense: 10
#       Energy consumption: 5
#               ^
#               |                  |1: WEAPON
#               |                  |Is available: False
#      ____     |    ____          |Attack: 25
#     |oooo|  ____  |oooo| ------> |Defense: 0
#     |oooo| '    ' |oooo|         |Energy consumption: 20
#     |oooo|/\_||_/\|oooo|
#     `----' / __ \  `----'           |2: LEFT ARM
#    '/  |#|/\/__\/\|#|  \'           |Is available: True
#    /  \|#|| |/\| ||#|/  \           |Attack: 16
#   / \_/|_|| |/\| ||_|\_/ \          |Defense: 20
#  |_\/    O\=----=/O    \/_|         |Energy consumption: 10
#  <_>      |=\__/=|      <_> ------> |
#  <_>      |------|      <_>         |3: RIGHT ARM
#  | |   ___|======|___   | |         |Is available: True
# // \\ / |O|======|O| \  //\\        |Attack: 16
# |  |  | |O+------+O| |  |  |        |Defense: 20
# |\/|  \_+/        \+_/  |\/|        |Energy consumption: 10
# \__/  _|||        |||_  \__/
#       | ||        || |          |4: LEFT LEG
#      [==|]        [|==]         |Is available: True
#      [===]        [===]         |Attack: 18
#       >_<          >_<          |Defense: 20
#      || ||        || ||         |Energy consumption: 15
#      || ||        || || ------> |
#      || ||        || ||         |5: RIGHT LEG
#    __|\_/|__    __|\_/|__       |Is available: True
#   /___n_n___\  /___n_n___\      |Attack: 18
#                                 |Defense: 20
#                                 |Energy consumption: 15
#
#
# What part should I use to attack?:
# Choose a number part: 1
#
# Olá, meu nome é: hu
# Temos 100 porcento de Energia restante
#
#       0: HEAD
#       Is available: True
#       Attack: 10
#       Defense: 10
#       Energy consumption: 5
#               ^
#               |                  |1: WEAPON
#               |                  |Is available: False
#      ____     |    ____          |Attack: 25
#     |oooo|  ____  |oooo| ------> |Defense: 0
#     |oooo| '    ' |oooo|         |Energy consumption: 20
#     |oooo|/\_||_/\|oooo|
#     `----' / __ \  `----'           |2: LEFT ARM
#    '/  |#|/\/__\/\|#|  \'           |Is available: True
#    /  \|#|| |/\| ||#|/  \           |Attack: 16
#   / \_/|_|| |/\| ||_|\_/ \          |Defense: 20
#  |_\/    O\=----=/O    \/_|         |Energy consumption: 10
#  <_>      |=\__/=|      <_> ------> |
#  <_>      |------|      <_>         |3: RIGHT ARM
#  | |   ___|======|___   | |         |Is available: True
# // \\ / |O|======|O| \  //\\        |Attack: 16
# |  |  | |O+------+O| |  |  |        |Defense: 20
# |\/|  \_+/        \+_/  |\/|        |Energy consumption: 10
# \__/  _|||        |||_  \__/
#       | ||        || |          |4: LEFT LEG
#      [==|]        [|==]         |Is available: True
#      [===]        [===]         |Attack: 18
#       >_<          >_<          |Defense: 20
#      || ||        || ||         |Energy consumption: 15
#      || ||        || || ------> |
#      || ||        || ||         |5: RIGHT LEG
#    __|\_/|__    __|\_/|__       |Is available: True
#   /___n_n___\  /___n_n___\      |Attack: 18
#                                 |Defense: 20
#                                 |Energy consumption: 15
#
#
# Which part of the enemy should we attack?
# Choose a enemy number part to attack: 5
#
# Olá, meu nome é: hu
# Temos 100 porcento de Energia restante
#
#       0: HEAD
#       Is available: True
#       Attack: 10
#       Defense: 10
#       Energy consumption: 5
#               ^
#               |                  |1: WEAPON
#               |                  |Is available: False
#      ____     |    ____          |Attack: 25
#     |oooo|  ____  |oooo| ------> |Defense: 0
#     |oooo| '    ' |oooo|         |Energy consumption: 20
#     |oooo|/\_||_/\|oooo|
#     `----' / __ \  `----'           |2: LEFT ARM
#    '/  |#|/\/__\/\|#|  \'           |Is available: True
#    /  \|#|| |/\| ||#|/  \           |Attack: 16
#   / \_/|_|| |/\| ||_|\_/ \          |Defense: 20
#  |_\/    O\=----=/O    \/_|         |Energy consumption: 10
#  <_>      |=\__/=|      <_> ------> |
#  <_>      |------|      <_>         |3: RIGHT ARM
#  | |   ___|======|___   | |         |Is available: True
# // \\ / |O|======|O| \  //\\        |Attack: 16
# |  |  | |O+------+O| |  |  |        |Defense: 20
# |\/|  \_+/        \+_/  |\/|        |Energy consumption: 10
# \__/  _|||        |||_  \__/
#       | ||        || |          |4: LEFT LEG
#      [==|]        [|==]         |Is available: True
#      [===]        [===]         |Attack: 18
#       >_<          >_<          |Defense: 20
#      || ||        || ||         |Energy consumption: 15
#      || ||        || || ------> |
#      || ||        || ||         |5: RIGHT LEG
#    __|\_/|__    __|\_/|__       |Is available: False
#   /___n_n___\  /___n_n___\      |Attack: 18
#                                 |Defense: 0
#                                 |Energy consumption: 15
#
#
# What part should I use to attack?:
# Choose a number part: 4
#
# Olá, meu nome é: ko
# Temos 80 porcento de Energia restante
#
#       0: HEAD
#       Is available: True
#       Attack: 10
#       Defense: 10
#       Energy consumption: 5
#               ^
#               |                  |1: WEAPON
#               |                  |Is available: False
#      ____     |    ____          |Attack: 25
#     |oooo|  ____  |oooo| ------> |Defense: 0
#     |oooo| '    ' |oooo|         |Energy consumption: 20
#     |oooo|/\_||_/\|oooo|
#     `----' / __ \  `----'           |2: LEFT ARM
#    '/  |#|/\/__\/\|#|  \'           |Is available: True
#    /  \|#|| |/\| ||#|/  \           |Attack: 16
#   / \_/|_|| |/\| ||_|\_/ \          |Defense: 20
#  |_\/    O\=----=/O    \/_|         |Energy consumption: 10
#  <_>      |=\__/=|      <_> ------> |
#  <_>      |------|      <_>         |3: RIGHT ARM
#  | |   ___|======|___   | |         |Is available: True
# // \\ / |O|======|O| \  //\\        |Attack: 16
# |  |  | |O+------+O| |  |  |        |Defense: 20
# |\/|  \_+/        \+_/  |\/|        |Energy consumption: 10
# \__/  _|||        |||_  \__/
#       | ||        || |          |4: LEFT LEG
#      [==|]        [|==]         |Is available: True
#      [===]        [===]         |Attack: 18
#       >_<          >_<          |Defense: 20
#      || ||        || ||         |Energy consumption: 15
#      || ||        || || ------> |
#      || ||        || ||         |5: RIGHT LEG
#    __|\_/|__    __|\_/|__       |Is available: True
#   /___n_n___\  /___n_n___\      |Attack: 18
#                                 |Defense: 20
#                                 |Energy consumption: 15
#
#
# Which part of the enemy should we attack?
# Choose a enemy number part to attack: 5
#
# Olá, meu nome é: ko
# Temos 80 porcento de Energia restante
#
#       0: HEAD
#       Is available: True
#       Attack: 10
#       Defense: 10
#       Energy consumption: 5
#               ^
#               |                  |1: WEAPON
#               |                  |Is available: False
#      ____     |    ____          |Attack: 25
#     |oooo|  ____  |oooo| ------> |Defense: 0
#     |oooo| '    ' |oooo|         |Energy consumption: 20
#     |oooo|/\_||_/\|oooo|
#     `----' / __ \  `----'           |2: LEFT ARM
#    '/  |#|/\/__\/\|#|  \'           |Is available: True
#    /  \|#|| |/\| ||#|/  \           |Attack: 16
#   / \_/|_|| |/\| ||_|\_/ \          |Defense: 20
#  |_\/    O\=----=/O    \/_|         |Energy consumption: 10
#  <_>      |=\__/=|      <_> ------> |
#  <_>      |------|      <_>         |3: RIGHT ARM
#  | |   ___|======|___   | |         |Is available: True
# // \\ / |O|======|O| \  //\\        |Attack: 16
# |  |  | |O+------+O| |  |  |        |Defense: 20
# |\/|  \_+/        \+_/  |\/|        |Energy consumption: 10
# \__/  _|||        |||_  \__/
#       | ||        || |          |4: LEFT LEG
#      [==|]        [|==]         |Is available: True
#      [===]        [===]         |Attack: 18
#       >_<          >_<          |Defense: 20
#      || ||        || ||         |Energy consumption: 15
#      || ||        || || ------> |
#      || ||        || ||         |5: RIGHT LEG
#    __|\_/|__    __|\_/|__       |Is available: True
#   /___n_n___\  /___n_n___\      |Attack: 18
#                                 |Defense: 2
#                                 |Energy consumption: 15
#
#
# What part should I use to attack?:
# Choose a number part: 1
#
# Olá, meu nome é: hu
# Temos 85 porcento de Energia restante
#
#       0: HEAD
#       Is available: True
#       Attack: 10
#       Defense: 10
#       Energy consumption: 5
#               ^
#               |                  |1: WEAPON
#               |                  |Is available: False
#      ____     |    ____          |Attack: 25
#     |oooo|  ____  |oooo| ------> |Defense: 0
#     |oooo| '    ' |oooo|         |Energy consumption: 20
#     |oooo|/\_||_/\|oooo|
#     `----' / __ \  `----'           |2: LEFT ARM
#    '/  |#|/\/__\/\|#|  \'           |Is available: True
#    /  \|#|| |/\| ||#|/  \           |Attack: 16
#   / \_/|_|| |/\| ||_|\_/ \          |Defense: 20
#  |_\/    O\=----=/O    \/_|         |Energy consumption: 10
#  <_>      |=\__/=|      <_> ------> |
#  <_>      |------|      <_>         |3: RIGHT ARM
#  | |   ___|======|___   | |         |Is available: True
# // \\ / |O|======|O| \  //\\        |Attack: 16
# |  |  | |O+------+O| |  |  |        |Defense: 20
# |\/|  \_+/        \+_/  |\/|        |Energy consumption: 10
# \__/  _|||        |||_  \__/
#       | ||        || |          |4: LEFT LEG
#      [==|]        [|==]         |Is available: True
#      [===]        [===]         |Attack: 18
#       >_<          >_<          |Defense: 20
#      || ||        || ||         |Energy consumption: 15
#      || ||        || || ------> |
#      || ||        || ||         |5: RIGHT LEG
#    __|\_/|__    __|\_/|__       |Is available: False
#   /___n_n___\  /___n_n___\      |Attack: 18
#                                 |Defense: 0
#                                 |Energy consumption: 15
#
#
# Which part of the enemy should we attack?
# Choose a enemy number part to attack: 4
#
# Olá, meu nome é: hu
# Temos 85 porcento de Energia restante
#
#       0: HEAD
#       Is available: True
#       Attack: 10
#       Defense: 10
#       Energy consumption: 5
#               ^
#               |                  |1: WEAPON
#               |                  |Is available: False
#      ____     |    ____          |Attack: 25
#     |oooo|  ____  |oooo| ------> |Defense: 0
#     |oooo| '    ' |oooo|         |Energy consumption: 20
#     |oooo|/\_||_/\|oooo|
#     `----' / __ \  `----'           |2: LEFT ARM
#    '/  |#|/\/__\/\|#|  \'           |Is available: True
#    /  \|#|| |/\| ||#|/  \           |Attack: 16
#   / \_/|_|| |/\| ||_|\_/ \          |Defense: 20
#  |_\/    O\=----=/O    \/_|         |Energy consumption: 10
#  <_>      |=\__/=|      <_> ------> |
#  <_>      |------|      <_>         |3: RIGHT ARM
#  | |   ___|======|___   | |         |Is available: True
# // \\ / |O|======|O| \  //\\        |Attack: 16
# |  |  | |O+------+O| |  |  |        |Defense: 20
# |\/|  \_+/        \+_/  |\/|        |Energy consumption: 10
# \__/  _|||        |||_  \__/
#       | ||        || |          |4: LEFT LEG
#      [==|]        [|==]         |Is available: False
#      [===]        [===]         |Attack: 18
#       >_<          >_<          |Defense: 0
#      || ||        || ||         |Energy consumption: 15
#      || ||        || || ------> |
#      || ||        || ||         |5: RIGHT LEG
#    __|\_/|__    __|\_/|__       |Is available: False
#   /___n_n___\  /___n_n___\      |Attack: 18
#                                 |Defense: 0
#                                 |Energy consumption: 15
#
#
# What part should I use to attack?:
# Choose a number part: 3
#
# Olá, meu nome é: ko
# Temos 60 porcento de Energia restante
#
#       0: HEAD
#       Is available: True
#       Attack: 10
#       Defense: 10
#       Energy consumption: 5
#               ^
#               |                  |1: WEAPON
#               |                  |Is available: False
#      ____     |    ____          |Attack: 25
#     |oooo|  ____  |oooo| ------> |Defense: 0
#     |oooo| '    ' |oooo|         |Energy consumption: 20
#     |oooo|/\_||_/\|oooo|
#     `----' / __ \  `----'           |2: LEFT ARM
#    '/  |#|/\/__\/\|#|  \'           |Is available: True
#    /  \|#|| |/\| ||#|/  \           |Attack: 16
#   / \_/|_|| |/\| ||_|\_/ \          |Defense: 20
#  |_\/    O\=----=/O    \/_|         |Energy consumption: 10
#  <_>      |=\__/=|      <_> ------> |
#  <_>      |------|      <_>         |3: RIGHT ARM
#  | |   ___|======|___   | |         |Is available: True
# // \\ / |O|======|O| \  //\\        |Attack: 16
# |  |  | |O+------+O| |  |  |        |Defense: 20
# |\/|  \_+/        \+_/  |\/|        |Energy consumption: 10
# \__/  _|||        |||_  \__/
#       | ||        || |          |4: LEFT LEG
#      [==|]        [|==]         |Is available: True
#      [===]        [===]         |Attack: 18
#       >_<          >_<          |Defense: 20
#      || ||        || ||         |Energy consumption: 15
#      || ||        || || ------> |
#      || ||        || ||         |5: RIGHT LEG
#    __|\_/|__    __|\_/|__       |Is available: True
#   /___n_n___\  /___n_n___\      |Attack: 18
#                                 |Defense: 2
#                                 |Energy consumption: 15
#
#
# Which part of the enemy should we attack?
# Choose a enemy number part to attack: 2
#
# Olá, meu nome é: ko
# Temos 60 porcento de Energia restante
#
#       0: HEAD
#       Is available: True
#       Attack: 10
#       Defense: 10
#       Energy consumption: 5
#               ^
#               |                  |1: WEAPON
#               |                  |Is available: False
#      ____     |    ____          |Attack: 25
#     |oooo|  ____  |oooo| ------> |Defense: 0
#     |oooo| '    ' |oooo|         |Energy consumption: 20
#     |oooo|/\_||_/\|oooo|
#     `----' / __ \  `----'           |2: LEFT ARM
#    '/  |#|/\/__\/\|#|  \'           |Is available: True
#    /  \|#|| |/\| ||#|/  \           |Attack: 16
#   / \_/|_|| |/\| ||_|\_/ \          |Defense: 4
#  |_\/    O\=----=/O    \/_|         |Energy consumption: 10
#  <_>      |=\__/=|      <_> ------> |
#  <_>      |------|      <_>         |3: RIGHT ARM
#  | |   ___|======|___   | |         |Is available: True
# // \\ / |O|======|O| \  //\\        |Attack: 16
# |  |  | |O+------+O| |  |  |        |Defense: 20
# |\/|  \_+/        \+_/  |\/|        |Energy consumption: 10
# \__/  _|||        |||_  \__/
#       | ||        || |          |4: LEFT LEG
#      [==|]        [|==]         |Is available: True
#      [===]        [===]         |Attack: 18
#       >_<          >_<          |Defense: 20
#      || ||        || ||         |Energy consumption: 15
#      || ||        || || ------> |
#      || ||        || ||         |5: RIGHT LEG
#    __|\_/|__    __|\_/|__       |Is available: True
#   /___n_n___\  /___n_n___\      |Attack: 18
#                                 |Defense: 2
#                                 |Energy consumption: 15
#
#
# What part should I use to attack?:
# Choose a number part: 1
#
# Olá, meu nome é: hu
# Temos 75 porcento de Energia restante
#
#       0: HEAD
#       Is available: True
#       Attack: 10
#       Defense: 10
#       Energy consumption: 5
#               ^
#               |                  |1: WEAPON
#               |                  |Is available: False
#      ____     |    ____          |Attack: 25
#     |oooo|  ____  |oooo| ------> |Defense: 0
#     |oooo| '    ' |oooo|         |Energy consumption: 20
#     |oooo|/\_||_/\|oooo|
#     `----' / __ \  `----'           |2: LEFT ARM
#    '/  |#|/\/__\/\|#|  \'           |Is available: True
#    /  \|#|| |/\| ||#|/  \           |Attack: 16
#   / \_/|_|| |/\| ||_|\_/ \          |Defense: 20
#  |_\/    O\=----=/O    \/_|         |Energy consumption: 10
#  <_>      |=\__/=|      <_> ------> |
#  <_>      |------|      <_>         |3: RIGHT ARM
#  | |   ___|======|___   | |         |Is available: True
# // \\ / |O|======|O| \  //\\        |Attack: 16
# |  |  | |O+------+O| |  |  |        |Defense: 20
# |\/|  \_+/        \+_/  |\/|        |Energy consumption: 10
# \__/  _|||        |||_  \__/
#       | ||        || |          |4: LEFT LEG
#      [==|]        [|==]         |Is available: False
#      [===]        [===]         |Attack: 18
#       >_<          >_<          |Defense: 0
#      || ||        || ||         |Energy consumption: 15
#      || ||        || || ------> |
#      || ||        || ||         |5: RIGHT LEG
#    __|\_/|__    __|\_/|__       |Is available: False
#   /___n_n___\  /___n_n___\      |Attack: 18
#                                 |Defense: 0
#                                 |Energy consumption: 15
#
#
# Which part of the enemy should we attack?
# Choose a enemy number part to attack: 3
#
# Olá, meu nome é: hu
# Temos 75 porcento de Energia restante
#
#       0: HEAD
#       Is available: True
#       Attack: 10
#       Defense: 10
#       Energy consumption: 5
#               ^
#               |                  |1: WEAPON
#               |                  |Is available: False
#      ____     |    ____          |Attack: 25
#     |oooo|  ____  |oooo| ------> |Defense: 0
#     |oooo| '    ' |oooo|         |Energy consumption: 20
#     |oooo|/\_||_/\|oooo|
#     `----' / __ \  `----'           |2: LEFT ARM
#    '/  |#|/\/__\/\|#|  \'           |Is available: True
#    /  \|#|| |/\| ||#|/  \           |Attack: 16
#   / \_/|_|| |/\| ||_|\_/ \          |Defense: 20
#  |_\/    O\=----=/O    \/_|         |Energy consumption: 10
#  <_>      |=\__/=|      <_> ------> |
#  <_>      |------|      <_>         |3: RIGHT ARM
#  | |   ___|======|___   | |         |Is available: False
# // \\ / |O|======|O| \  //\\        |Attack: 16
# |  |  | |O+------+O| |  |  |        |Defense: 0
# |\/|  \_+/        \+_/  |\/|        |Energy consumption: 10
# \__/  _|||        |||_  \__/
#       | ||        || |          |4: LEFT LEG
#      [==|]        [|==]         |Is available: False
#      [===]        [===]         |Attack: 18
#       >_<          >_<          |Defense: 0
#      || ||        || ||         |Energy consumption: 15
#      || ||        || || ------> |
#      || ||        || ||         |5: RIGHT LEG
#    __|\_/|__    __|\_/|__       |Is available: False
#   /___n_n___\  /___n_n___\      |Attack: 18
#                                 |Defense: 0
#                                 |Energy consumption: 15
#
#
# What part should I use to attack?:
# Choose a number part: 5
#
# Olá, meu nome é: ko
# Temos 40 porcento de Energia restante
#
#       0: HEAD
#       Is available: True
#       Attack: 10
#       Defense: 10
#       Energy consumption: 5
#               ^
#               |                  |1: WEAPON
#               |                  |Is available: False
#      ____     |    ____          |Attack: 25
#     |oooo|  ____  |oooo| ------> |Defense: 0
#     |oooo| '    ' |oooo|         |Energy consumption: 20
#     |oooo|/\_||_/\|oooo|
#     `----' / __ \  `----'           |2: LEFT ARM
#    '/  |#|/\/__\/\|#|  \'           |Is available: True
#    /  \|#|| |/\| ||#|/  \           |Attack: 16
#   / \_/|_|| |/\| ||_|\_/ \          |Defense: 4
#  |_\/    O\=----=/O    \/_|         |Energy consumption: 10
#  <_>      |=\__/=|      <_> ------> |
#  <_>      |------|      <_>         |3: RIGHT ARM
#  | |   ___|======|___   | |         |Is available: True
# // \\ / |O|======|O| \  //\\        |Attack: 16
# |  |  | |O+------+O| |  |  |        |Defense: 20
# |\/|  \_+/        \+_/  |\/|        |Energy consumption: 10
# \__/  _|||        |||_  \__/
#       | ||        || |          |4: LEFT LEG
#      [==|]        [|==]         |Is available: True
#      [===]        [===]         |Attack: 18
#       >_<          >_<          |Defense: 20
#      || ||        || ||         |Energy consumption: 15
#      || ||        || || ------> |
#      || ||        || ||         |5: RIGHT LEG
#    __|\_/|__    __|\_/|__       |Is available: True
#   /___n_n___\  /___n_n___\      |Attack: 18
#                                 |Defense: 2
#                                 |Energy consumption: 15
#
#
# Which part of the enemy should we attack?
# Choose a enemy number part to attack: 1
#
# Olá, meu nome é: ko
# Temos 40 porcento de Energia restante
#
#       0: HEAD
#       Is available: True
#       Attack: 10
#       Defense: 10
#       Energy consumption: 5
#               ^
#               |                  |1: WEAPON
#               |                  |Is available: False
#      ____     |    ____          |Attack: 25
#     |oooo|  ____  |oooo| ------> |Defense: 0
#     |oooo| '    ' |oooo|         |Energy consumption: 20
#     |oooo|/\_||_/\|oooo|
#     `----' / __ \  `----'           |2: LEFT ARM
#    '/  |#|/\/__\/\|#|  \'           |Is available: True
#    /  \|#|| |/\| ||#|/  \           |Attack: 16
#   / \_/|_|| |/\| ||_|\_/ \          |Defense: 4
#  |_\/    O\=----=/O    \/_|         |Energy consumption: 10
#  <_>      |=\__/=|      <_> ------> |
#  <_>      |------|      <_>         |3: RIGHT ARM
#  | |   ___|======|___   | |         |Is available: True
# // \\ / |O|======|O| \  //\\        |Attack: 16
# |  |  | |O+------+O| |  |  |        |Defense: 20
# |\/|  \_+/        \+_/  |\/|        |Energy consumption: 10
# \__/  _|||        |||_  \__/
#       | ||        || |          |4: LEFT LEG
#      [==|]        [|==]         |Is available: True
#      [===]        [===]         |Attack: 18
#       >_<          >_<          |Defense: 20
#      || ||        || ||         |Energy consumption: 15
#      || ||        || || ------> |
#      || ||        || ||         |5: RIGHT LEG
#    __|\_/|__    __|\_/|__       |Is available: True
#   /___n_n___\  /___n_n___\      |Attack: 18
#                                 |Defense: 2
#                                 |Energy consumption: 15
#
#
# What part should I use to attack?:
# Choose a number part: 1
#
# Olá, meu nome é: hu
# Temos 60 porcento de Energia restante
#
#       0: HEAD
#       Is available: True
#       Attack: 10
#       Defense: 10
#       Energy consumption: 5
#               ^
#               |                  |1: WEAPON
#               |                  |Is available: False
#      ____     |    ____          |Attack: 25
#     |oooo|  ____  |oooo| ------> |Defense: 0
#     |oooo| '    ' |oooo|         |Energy consumption: 20
#     |oooo|/\_||_/\|oooo|
#     `----' / __ \  `----'           |2: LEFT ARM
#    '/  |#|/\/__\/\|#|  \'           |Is available: True
#    /  \|#|| |/\| ||#|/  \           |Attack: 16
#   / \_/|_|| |/\| ||_|\_/ \          |Defense: 20
#  |_\/    O\=----=/O    \/_|         |Energy consumption: 10
#  <_>      |=\__/=|      <_> ------> |
#  <_>      |------|      <_>         |3: RIGHT ARM
#  | |   ___|======|___   | |         |Is available: False
# // \\ / |O|======|O| \  //\\        |Attack: 16
# |  |  | |O+------+O| |  |  |        |Defense: 0
# |\/|  \_+/        \+_/  |\/|        |Energy consumption: 10
# \__/  _|||        |||_  \__/
#       | ||        || |          |4: LEFT LEG
#      [==|]        [|==]         |Is available: False
#      [===]        [===]         |Attack: 18
#       >_<          >_<          |Defense: 0
#      || ||        || ||         |Energy consumption: 15
#      || ||        || || ------> |
#      || ||        || ||         |5: RIGHT LEG
#    __|\_/|__    __|\_/|__       |Is available: False
#   /___n_n___\  /___n_n___\      |Attack: 18
#                                 |Defense: 0
#                                 |Energy consumption: 15
#
#
# Which part of the enemy should we attack?
# Choose a enemy number part to attack: 2
#
# Olá, meu nome é: hu
# Temos 60 porcento de Energia restante
#
#       0: HEAD
#       Is available: True
#       Attack: 10
#       Defense: 10
#       Energy consumption: 5
#               ^
#               |                  |1: WEAPON
#               |                  |Is available: False
#      ____     |    ____          |Attack: 25
#     |oooo|  ____  |oooo| ------> |Defense: 0
#     |oooo| '    ' |oooo|         |Energy consumption: 20
#     |oooo|/\_||_/\|oooo|
#     `----' / __ \  `----'           |2: LEFT ARM
#    '/  |#|/\/__\/\|#|  \'           |Is available: False
#    /  \|#|| |/\| ||#|/  \           |Attack: 16
#   / \_/|_|| |/\| ||_|\_/ \          |Defense: 0
#  |_\/    O\=----=/O    \/_|         |Energy consumption: 10
#  <_>      |=\__/=|      <_> ------> |
#  <_>      |------|      <_>         |3: RIGHT ARM
#  | |   ___|======|___   | |         |Is available: False
# // \\ / |O|======|O| \  //\\        |Attack: 16
# |  |  | |O+------+O| |  |  |        |Defense: 0
# |\/|  \_+/        \+_/  |\/|        |Energy consumption: 10
# \__/  _|||        |||_  \__/
#       | ||        || |          |4: LEFT LEG
#      [==|]        [|==]         |Is available: False
#      [===]        [===]         |Attack: 18
#       >_<          >_<          |Defense: 0
#      || ||        || ||         |Energy consumption: 15
#      || ||        || || ------> |
#      || ||        || ||         |5: RIGHT LEG
#    __|\_/|__    __|\_/|__       |Is available: False
#   /___n_n___\  /___n_n___\      |Attack: 18
#                                 |Defense: 0
#                                 |Energy consumption: 15
#
#
# What part should I use to attack?:
# Choose a number part: 4
#
# Olá, meu nome é: ko
# Temos 20 porcento de Energia restante
#
#       0: HEAD
#       Is available: True
#       Attack: 10
#       Defense: 10
#       Energy consumption: 5
#               ^
#               |                  |1: WEAPON
#               |                  |Is available: False
#      ____     |    ____          |Attack: 25
#     |oooo|  ____  |oooo| ------> |Defense: 0
#     |oooo| '    ' |oooo|         |Energy consumption: 20
#     |oooo|/\_||_/\|oooo|
#     `----' / __ \  `----'           |2: LEFT ARM
#    '/  |#|/\/__\/\|#|  \'           |Is available: True
#    /  \|#|| |/\| ||#|/  \           |Attack: 16
#   / \_/|_|| |/\| ||_|\_/ \          |Defense: 4
#  |_\/    O\=----=/O    \/_|         |Energy consumption: 10
#  <_>      |=\__/=|      <_> ------> |
#  <_>      |------|      <_>         |3: RIGHT ARM
#  | |   ___|======|___   | |         |Is available: True
# // \\ / |O|======|O| \  //\\        |Attack: 16
# |  |  | |O+------+O| |  |  |        |Defense: 20
# |\/|  \_+/        \+_/  |\/|        |Energy consumption: 10
# \__/  _|||        |||_  \__/
#       | ||        || |          |4: LEFT LEG
#      [==|]        [|==]         |Is available: True
#      [===]        [===]         |Attack: 18
#       >_<          >_<          |Defense: 20
#      || ||        || ||         |Energy consumption: 15
#      || ||        || || ------> |
#      || ||        || ||         |5: RIGHT LEG
#    __|\_/|__    __|\_/|__       |Is available: True
#   /___n_n___\  /___n_n___\      |Attack: 18
#                                 |Defense: 2
#                                 |Energy consumption: 15
#
#
# Which part of the enemy should we attack?
# Choose a enemy number part to attack: 1
#
# Olá, meu nome é: ko
# Temos 20 porcento de Energia restante
#
#       0: HEAD
#       Is available: True
#       Attack: 10
#       Defense: 10
#       Energy consumption: 5
#               ^
#               |                  |1: WEAPON
#               |                  |Is available: False
#      ____     |    ____          |Attack: 25
#     |oooo|  ____  |oooo| ------> |Defense: 0
#     |oooo| '    ' |oooo|         |Energy consumption: 20
#     |oooo|/\_||_/\|oooo|
#     `----' / __ \  `----'           |2: LEFT ARM
#    '/  |#|/\/__\/\|#|  \'           |Is available: True
#    /  \|#|| |/\| ||#|/  \           |Attack: 16
#   / \_/|_|| |/\| ||_|\_/ \          |Defense: 4
#  |_\/    O\=----=/O    \/_|         |Energy consumption: 10
#  <_>      |=\__/=|      <_> ------> |
#  <_>      |------|      <_>         |3: RIGHT ARM
#  | |   ___|======|___   | |         |Is available: True
# // \\ / |O|======|O| \  //\\        |Attack: 16
# |  |  | |O+------+O| |  |  |        |Defense: 20
# |\/|  \_+/        \+_/  |\/|        |Energy consumption: 10
# \__/  _|||        |||_  \__/
#       | ||        || |          |4: LEFT LEG
#      [==|]        [|==]         |Is available: True
#      [===]        [===]         |Attack: 18
#       >_<          >_<          |Defense: 20
#      || ||        || ||         |Energy consumption: 15
#      || ||        || || ------> |
#      || ||        || ||         |5: RIGHT LEG
#    __|\_/|__    __|\_/|__       |Is available: True
#   /___n_n___\  /___n_n___\      |Attack: 18
#                                 |Defense: 2
#                                 |Energy consumption: 15
#
#
# What part should I use to attack?:
# Choose a number part: 1
#
# Olá, meu nome é: hu
# Temos 45 porcento de Energia restante
#
#       0: HEAD
#       Is available: True
#       Attack: 10
#       Defense: 10
#       Energy consumption: 5
#               ^
#               |                  |1: WEAPON
#               |                  |Is available: False
#      ____     |    ____          |Attack: 25
#     |oooo|  ____  |oooo| ------> |Defense: 0
#     |oooo| '    ' |oooo|         |Energy consumption: 20
#     |oooo|/\_||_/\|oooo|
#     `----' / __ \  `----'           |2: LEFT ARM
#    '/  |#|/\/__\/\|#|  \'           |Is available: False
#    /  \|#|| |/\| ||#|/  \           |Attack: 16
#   / \_/|_|| |/\| ||_|\_/ \          |Defense: 0
#  |_\/    O\=----=/O    \/_|         |Energy consumption: 10
#  <_>      |=\__/=|      <_> ------> |
#  <_>      |------|      <_>         |3: RIGHT ARM
#  | |   ___|======|___   | |         |Is available: False
# // \\ / |O|======|O| \  //\\        |Attack: 16
# |  |  | |O+------+O| |  |  |        |Defense: 0
# |\/|  \_+/        \+_/  |\/|        |Energy consumption: 10
# \__/  _|||        |||_  \__/
#       | ||        || |          |4: LEFT LEG
#      [==|]        [|==]         |Is available: False
#      [===]        [===]         |Attack: 18
#       >_<          >_<          |Defense: 0
#      || ||        || ||         |Energy consumption: 15
#      || ||        || || ------> |
#      || ||        || ||         |5: RIGHT LEG
#    __|\_/|__    __|\_/|__       |Is available: False
#   /___n_n___\  /___n_n___\      |Attack: 18
#                                 |Defense: 0
#                                 |Energy consumption: 15
#
#
# Which part of the enemy should we attack?
# Choose a enemy number part to attack: 1
#
# Olá, meu nome é: hu
# Temos 45 porcento de Energia restante
#
#       0: HEAD
#       Is available: True
#       Attack: 10
#       Defense: 10
#       Energy consumption: 5
#               ^
#               |                  |1: WEAPON
#               |                  |Is available: False
#      ____     |    ____          |Attack: 25
#     |oooo|  ____  |oooo| ------> |Defense: 0
#     |oooo| '    ' |oooo|         |Energy consumption: 20
#     |oooo|/\_||_/\|oooo|
#     `----' / __ \  `----'           |2: LEFT ARM
#    '/  |#|/\/__\/\|#|  \'           |Is available: False
#    /  \|#|| |/\| ||#|/  \           |Attack: 16
#   / \_/|_|| |/\| ||_|\_/ \          |Defense: 0
#  |_\/    O\=----=/O    \/_|         |Energy consumption: 10
#  <_>      |=\__/=|      <_> ------> |
#  <_>      |------|      <_>         |3: RIGHT ARM
#  | |   ___|======|___   | |         |Is available: False
# // \\ / |O|======|O| \  //\\        |Attack: 16
# |  |  | |O+------+O| |  |  |        |Defense: 0
# |\/|  \_+/        \+_/  |\/|        |Energy consumption: 10
# \__/  _|||        |||_  \__/
#       | ||        || |          |4: LEFT LEG
#      [==|]        [|==]         |Is available: False
#      [===]        [===]         |Attack: 18
#       >_<          >_<          |Defense: 0
#      || ||        || ||         |Energy consumption: 15
#      || ||        || || ------> |
#      || ||        || ||         |5: RIGHT LEG
#    __|\_/|__    __|\_/|__       |Is available: False
#   /___n_n___\  /___n_n___\      |Attack: 18
#                                 |Defense: 0
#                                 |Energy consumption: 15
#
#
# What part should I use to attack?:
# Choose a number part: 0
#
# Olá, meu nome é: ko
# Temos 0 porcento de Energia restante
#
#       0: HEAD
#       Is available: True
#       Attack: 10
#       Defense: 10
#       Energy consumption: 5
#               ^
#               |                  |1: WEAPON
#               |                  |Is available: False
#      ____     |    ____          |Attack: 25
#     |oooo|  ____  |oooo| ------> |Defense: 0
#     |oooo| '    ' |oooo|         |Energy consumption: 20
#     |oooo|/\_||_/\|oooo|
#     `----' / __ \  `----'           |2: LEFT ARM
#    '/  |#|/\/__\/\|#|  \'           |Is available: True
#    /  \|#|| |/\| ||#|/  \           |Attack: 16
#   / \_/|_|| |/\| ||_|\_/ \          |Defense: 4
#  |_\/    O\=----=/O    \/_|         |Energy consumption: 10
#  <_>      |=\__/=|      <_> ------> |
#  <_>      |------|      <_>         |3: RIGHT ARM
#  | |   ___|======|___   | |         |Is available: True
# // \\ / |O|======|O| \  //\\        |Attack: 16
# |  |  | |O+------+O| |  |  |        |Defense: 20
# |\/|  \_+/        \+_/  |\/|        |Energy consumption: 10
# \__/  _|||        |||_  \__/
#       | ||        || |          |4: LEFT LEG
#      [==|]        [|==]         |Is available: True
#      [===]        [===]         |Attack: 18
#       >_<          >_<          |Defense: 20
#      || ||        || ||         |Energy consumption: 15
#      || ||        || || ------> |
#      || ||        || ||         |5: RIGHT LEG
#    __|\_/|__    __|\_/|__       |Is available: True
#   /___n_n___\  /___n_n___\      |Attack: 18
#                                 |Defense: 2
#                                 |Energy consumption: 15
#
#
# Which part of the enemy should we attack?
# Choose a enemy number part to attack: 1
# Congratulations, you won
