# %% [markdown]
# ### Bucle While
# ![image](data:image/png;base64,...)

# %%
## Vamos fazer alguns exemplos
## Vamos fazer o exercício para número, mas dentro de uma lista de números
## Vamos parar o ciclo dos loopings, assim que encontrarmos o par

is_even = False
index = 0
numbers = [11, 5, 13, 8, 34] # index = 0,1,2,3,4

while (not is_even): # enquanto miha condição for True
    if ((numbers[index] % 2) == 0):
        is_even = True # condição de parada
        print("Even number found: " + str(numbers[index]))
    
    index += 1 # index = index + 1
# Out:
# Even number found: 8
# O index final é: 4

# %%
## Lembre-se que a condição pode ser qualquer expressão
## Que avalia uma condição lógica, você pode usar os operadores relacionais ou os lógicos


## O que você acha que acontece neste caso?
## Ele será executado para sempre, então, após um momento, pare de executar manualmente
while "OPPS":
    print("We are inside the loop")
# Out:
# A saída de streaming foi truncada nas últimas 5000 linhas.
# We are inside the loop
# We are inside the loop
# We are inside the loop
# We are inside the loop
# We are inside the loop
# We are inside the loop
# We are inside the loop
# We are inside the loop
# We are inside the loop
# We are inside the loop
# We are inside the loop
# We are inside the loop
# We are inside the loop
# We are inside the loop
# We are inside the loop
# We are inside the loop
# We are inside the loop
# We are inside the loop
# We are inside the loop
# We are inside the loop
# We are inside the loop
# We are inside the loop
# We are inside the loop
# We are inside the loop
# We are inside the loop
# We are inside the loop
# We are inside the loop
# We are inside the loop
# We are inside the loop
# We are inside the loop
# We are inside the loop
# We are inside the loop
# We are inside the loop
# We are inside the loop
# We are inside the loop
# We are inside the loop
# We are inside the loop
# ...

# %% [markdown]
# ### Bucle For In
# ![second](data:image/png;base64,...)

# %%
## Vamos usar o mesmo exemplo que usamos para o loop 'while',
## Só que desta vez vamos iterar a lista usando o 'for' ... 'in'

numbers = [79, 3, 4, 5, 6]
for number in numbers:
    if number % 2 == 0:
        print("The number is even: " + str(number))
        break # condição de parada

## A palavra break é para quebrar a iteração do laço
# Out:
# The number is even: 4

# %%
## Vejamos o seguinte exemplo:

for number in "numbers":
    print("We are in the loop")
    
## Você percebeu que ele entra no ciclo de iteração?
## Podemos iterar uma string, mas o que exatamente vemos:

for letter in "Numbers":
    print(letter)
    
## Podemos ver cada letra dentro da string
# Out:
# We are in the loop
# We are in the loop
# We are in the loop
# We are in the loop
# We are in the loop
# We are in the loop
# We are in the loop
# N
# u
# m
# b
# e
# r
# s

# %% [markdown]
# ## Exercícios

# %% [markdown]
# ### Exercício 1
#
# Scrabble é um jogo onde os jogadores marcam pontos soletrando palavras. As palavras são pontuadas adicionando os valores de pontos de cada letra individual. Complete o método dentro da classe Game que, dada uma palavra, retorna a pontuação total da palavra com base na seguinte divisão de pontos:
#
# ```python
# scores = {"a": 1, "c": 3, "b": 3, "e": 1, "d": 2, "g": 2,
#          "f": 4, "i": 1, "h": 4, "k": 5, "j": 8, "m": 3,
#          "l": 1, "o": 1, "n": 1, "q": 10, "p": 3, "s": 1,
#          "r": 1, "u": 1, "t": 1, "w": 4, "v": 4, "y": 4,
#          "x": 8, "z": 10}
# ```

# %%
class Game:
    
    def __init__(self):
        self.scores = {}
        
    def get_score(self, word):
        pass

# %%
game = Game()

score = game.get_score("Hello")

## Deve imprimir o somatório dos números associado a cada letra da palavra 'Hello'
print(score)
# Out:
# None

# %% [markdown]
# ### Exercício 2
#
# A seguir apresentamos uma lista de números que representam os saldos de várias contas bancárias, o problema é que para mostrá-los ao cliente, precisamos que sejam mostrados em porcentagem, converta todos os números em porcentagem e imprima a nova lista.

# %%
accounts = [0.12, 0.90, 0.89, 0.076, -0.0087, 0.78, 0.65]
percentage_accounts = []


print(percentage_accounts)
# Out:
# []

# %% [markdown]
# ### Exercício 3
#
# Até este poê nto vocjá conhece muito bem a função `print()`, e algo muito divertido que podemos fazer em python é desenhar padrões, desenhe o seguinte padrão, lembre-se que a solução deve incluir os loops que você aprendeu.
# ```
# *
# * *
# * * *
# * * * *
# * * * * *
# * * * *
# * * *
# * *
# *
# ```

# %%
# coloque o seu código aqui

# %% [markdown]
# ### Exercício 4
#
# Estamos testando um novo sistema de verificação de segurança, para o qual o usuário deve digitar sua senha e digitar um código de verificação, para o qual ele tem 3 tentativas, se falhar nas três tentativas, devemos imprimir `Sua conta foi bloqueada`, em caso você insira os dados corretos nas três tentativas que tiver, imprimiremos `Seus dados foram verificados`, use a função de entrada para que o usuário insira sua senha e seu código de verificação

# %%
### Em seguida, fornecemos as informações da conta
### password = !@#123
### verification_code = 9898

# %% [markdown]
# #### Exercício 5
#
# Há uma string 𝑠 de comprimento 3, composta por letras maiúsculas e minúsculas. Verifique se é igual a "SIM" (sem aspas), onde cada letra pode ser em qualquer caso. Por exemplo, "YES", "yEs", "Yes" são todos permitidos.
#
# Imprima "SIM" se a condição for satisfeita, caso contrário, imprima "NÃO"

# %%
s = "yes"

### coloque o seu código aqui
